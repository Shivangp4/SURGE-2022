# %%
import numpy as np
import matplotlib.pyplot as plt
from spacepy import pycdf
import pandas as pd

# %% [markdown]
# ### Reading cdf files and converting into txt

# %%
# cdf1 = pycdf.CDF('data1\mms1_fgm_srvy_l2_20220103_v5.328.0.cdf')
# np.savetxt("data1/mms1_fgm_r_gse_srvy_l2.txt", np.array(cdf1['mms1_fgm_r_gse_srvy_l2'][:,:]))
# cdf2 = pycdf.CDF('data1\mms2_fgm_srvy_l2_20220103_v5.328.0.cdf')
# cdf3 = pycdf.CDF('data1\mms3_fgm_srvy_l2_20220103_v5.328.0.cdf')
# cdf4 = pycdf.CDF('data1\mms4_fgm_srvy_l2_20220103_v5.328.0.cdf')
# np.savetxt("data1/mms2_fgm_r_gse_srvy_l2.txt", np.array(cdf2['mms2_fgm_r_gse_srvy_l2'][:,:]))
# np.savetxt("data1/mms3_fgm_r_gse_srvy_l2.txt", np.array(cdf3['mms3_fgm_r_gse_srvy_l2'][:,:]))
# np.savetxt("data1/mms4_fgm_r_gse_srvy_l2.txt", np.array(cdf4['mms4_fgm_r_gse_srvy_l2'][:,:]))
# np.savetxt("data1/mms1_fgm_srvy_l2_20220103_v5.328.0.txt", np.array(cdf1['mms1_fgm_b_gse_srvy_l2'][:,:]))
# np.savetxt("data1/mms2_fgm_srvy_l2_20220103_v5.328.0.txt", np.array(cdf2['mms2_fgm_b_gse_srvy_l2'][:,:]))
# np.savetxt("data1/mms3_fgm_srvy_l2_20220103_v5.328.0.txt", np.array(cdf3['mms3_fgm_b_gse_srvy_l2'][:,:]))
# np.savetxt("data1/mms4_fgm_srvy_l2_20220103_v5.328.0.txt", np.array(cdf4['mms4_fgm_b_gse_srvy_l2'][:,:]))

# %%
# with open('data1/mms1_t.txt', 'w') as f:
#     for i in (cdf1['Epoch']):
#         f.write(str((i-cdf1['Epoch'][0]).total_seconds())+"\n")
#     f.close()
    
# with open('data1/mms2_t.txt', 'w') as f:
#     for i in (cdf2['Epoch']):
#         f.write(str((i-cdf2['Epoch'][0]).total_seconds())+"\n")
#     f.close()
    
# with open('data1/mms3_t.txt', 'w') as f:
#     for i in (cdf3['Epoch']):
#         f.write(str((i-cdf3['Epoch'][0]).total_seconds())+"\n")
#     f.close()

# with open('data1/mms4_t.txt', 'w') as f:
#     for i in (cdf4['Epoch']):
#         f.write(str((i-cdf4['Epoch'][0]).total_seconds())+"\n")
#     f.close()

# %%
# cdf1 = pycdf.CDF('data1\mms1_fpi_fast_l2_dis-moms_20220101020000_v3.4.0.cdf')
# v1=np.mean(cdf1['mms1_dis_bulkv_gse_fast'][:],axis=0)
# cdf2 = pycdf.CDF('data1\mms2_fpi_fast_l2_dis-moms_20220101020000_v3.4.0.cdf')
# v2=np.mean(cdf2['mms2_dis_bulkv_gse_fast'][:],axis=0)
# cdf3 = pycdf.CDF('data1\mms3_fpi_fast_l2_dis-moms_20220101020000_v3.4.0.cdf')
# v3=np.mean(cdf3['mms3_dis_bulkv_gse_fast'][:],axis=0)
# cdf4 = pycdf.CDF('data1\mms4_fpi_fast_l2_dis-moms_20220101020000_v3.4.0.cdf')
# v4=np.mean(cdf4['mms4_dis_bulkv_gse_fast'][:],axis=0)
# with open('data1/mms_fpi_avg.txt', 'w') as f:
#     f.write(str(v1[0])+" "+str(v1[1])+" "+str(v1[2])+"\n"+str(v2[0])+" "+str(v2[1])+" "+str(v2[2])+"\n"+str(v3[0])+" "+str(v3[1])+" "+str(v3[2])+"\n"+str(v1[0])+" "+str(v4[1])+" "+str(v4[2]))
# f.close()

# %% [markdown]
# ### Reading magnetic field, position, time and velocity data from txt files and plotting their graphs

# %%
v=pd.read_table('data1/mms_fpi_avg.txt',header=None,sep=" ")
v1=np.array(v.T[0])
v2=np.array(v.T[1])
v3=np.array(v.T[2])
v4=np.array(v.T[3])

# %%
t1=pd.read_table('data1/mms1_t.txt',header=None,sep=" ")
t2=pd.read_table('data1/mms2_t.txt',header=None,sep=" ")
t3=pd.read_table('data1/mms3_t.txt',header=None,sep=" ")
t4=pd.read_table('data1/mms4_t.txt',header=None,sep=" ")

# %%
B_1 = pd.read_table('data1/mms1_fgm_srvy_l2_20220103_v5.328.0.txt',header=None,sep=" ")
B_2 = pd.read_table('data1/mms2_fgm_srvy_l2_20220103_v5.328.0.txt',header=None,sep=" ")
B_3 = pd.read_table('data1/mms3_fgm_srvy_l2_20220103_v5.328.0.txt',header=None,sep=" ")
B_4 = pd.read_table('data1/mms4_fgm_srvy_l2_20220103_v5.328.0.txt',header=None,sep=" ")
r_1=pd.read_table('data1/mms1_fgm_r_gse_srvy_l2.txt',header=None,sep=" ")
r_2=pd.read_table('data1/mms2_fgm_r_gse_srvy_l2.txt',header=None,sep=" ")
r_3=pd.read_table('data1/mms3_fgm_r_gse_srvy_l2.txt',header=None,sep=" ")
r_4=pd.read_table('data1/mms4_fgm_r_gse_srvy_l2.txt',header=None,sep=" ")

# %%
plt.plot(B_1)
plt.show()
plt.plot(B_2)
plt.show()
plt.plot(B_3)
plt.show()
plt.plot(B_4)
plt.show()

# %%
plt.plot(r_1)
plt.show()
plt.plot(r_2)
plt.show()
plt.plot(r_3)
plt.show()
plt.plot(r_4)
plt.show()
plt.plot(r_1)
plt.plot(r_2)
plt.plot(r_3)
plt.plot(r_4)
plt.show()

# %%
plt.plot(t1)
plt.plot(t2)
plt.plot(t3)
plt.plot(t4)
plt.show()

# %% [markdown]
# ### Interpolating r data and applying frozen in approximation

# %%
from scipy import interpolate
index=np.linspace(0,2883,2884).astype(int)
x1=interpolate.interp1d(index,r_1[0],kind='linear',fill_value='extrapolate')
y1=interpolate.interp1d(index,r_1[1],kind='linear',fill_value='extrapolate')
z1=interpolate.interp1d(index,r_1[2],kind='linear',fill_value='extrapolate')
x2=interpolate.interp1d(index,r_2[0],kind='linear',fill_value='extrapolate')
y2=interpolate.interp1d(index,r_2[1],kind='linear',fill_value='extrapolate')
z2=interpolate.interp1d(index,r_2[2],kind='linear',fill_value='extrapolate')
x3=interpolate.interp1d(index,r_3[0],kind='linear',fill_value='extrapolate')
y3=interpolate.interp1d(index,r_3[1],kind='linear',fill_value='extrapolate')
z3=interpolate.interp1d(index,r_3[2],kind='linear',fill_value='extrapolate')
x4=interpolate.interp1d(index,r_4[0],kind='linear',fill_value='extrapolate')
y4=interpolate.interp1d(index,r_4[1],kind='linear',fill_value='extrapolate')
z4=interpolate.interp1d(index,r_4[2],kind='linear',fill_value='extrapolate')

# %%
index=np.linspace(0,t1.shape[0]-1,t1.shape[0]).astype(int)
x_1=np.array(x1(index))-v1[0]*t1[0]
y_1=np.array(y1(index))-v1[1]*t1[0]
z_1=np.array(z1(index))-v1[2]*t1[0]
index=np.linspace(0,t1.shape[0]-1,t2.shape[0]).astype(int)
x_2=np.array(x2(index))-v2[0]*t2[0]
y_2=np.array(y2(index))-v2[1]*t2[0]
z_2=np.array(z2(index))-v2[2]*t2[0]
index=np.linspace(0,t1.shape[0]-1,t3.shape[0]).astype(int)
x_3=np.array(x3(index))-v3[0]*t3[0]
y_3=np.array(y3(index))-v3[1]*t3[0]
z_3=np.array(z3(index))-v3[2]*t3[0]
index=np.linspace(0,t1.shape[0]-1,t4.shape[0]).astype(int)
x_4=np.array(x4(index))-v4[0]*t4[0]
y_4=np.array(y4(index))-v4[1]*t4[0]
z_4=np.array(z4(index))-v4[2]*t4[0]

# %%
X=np.concatenate((x_1,x_2,x_3,x_4))
Y=np.concatenate((y_1,y_2,y_3,y_4))
Z=np.concatenate((z_1,z_2,z_3,z_4))

# %%
B=np.concatenate((B_1,B_2,B_3,B_4),axis=0)
B=B.transpose()

# %%
bx=B[0]-B[0].mean()
by=B[1]-B[1].mean()
bz=B[2]-B[2].mean()
b=np.ndarray([3,bx.size])
b[0]=bx
b[1]=by
b[2]=bz
print(b)
r=np.sqrt(X**2+Y**2+Z**2)
# Out:
# [[-2.00424377 -2.02342979 -2.02943174 ...  2.08650782  2.08591499
#    2.10250535]
#  [ 2.50446924  2.49835428  2.50783332 ...  4.18021854  4.18584665
#    4.19167121]
#  [ 1.37235211  1.45335977  1.50774514 ... -0.45972301 -0.47068668
#   -0.46179915]]

# %%
print(b)
plt.plot(r,b.T)
# Out:
# [[-2.00424377 -2.02342979 -2.02943174 ...  2.08650782  2.08591499
#    2.10250535]
#  [ 2.50446924  2.49835428  2.50783332 ...  4.18021854  4.18584665
#    4.19167121]
#  [ 1.37235211  1.45335977  1.50774514 ... -0.45972301 -0.47068668
#   -0.46179915]]
# ...

# %% [markdown]
# ### Finding the overall discrete dataset and finding the correlation function

# %%
index=np.linspace(np.min(r),np.max(r),1300000)
b_=interpolate.interp1d(r,b,kind='linear')
b_=np.array(b_(index))

# %%
print(b_)
plt.plot(index,b_.T)
# Out:
# [[-2.49753705 -2.09686015 -2.25179197 ...  2.18974406  2.20187165
#    2.18212509]
#  [ 2.51277193  2.52455311  2.51385773 ...  3.97505796  3.97570853
#    3.94810232]
#  [ 1.1231718   1.48697625  1.19791793 ... -0.44910085 -0.4425726
#   -0.45387054]]
# ...

# %%
r_max=999*(index[1]-index[0]) 
Rc=np.ndarray(1000) #correlation function
for i in range(1000):
    Rc[i]=np.mean(b_.T[:1300000-i]*b_.T[i:])
Rc=Rc/np.mean(b_*b_)

# %%
# print(Rc)
plt.scatter(np.linspace(0,999,1000),Rc,s=0.4)

# %% [markdown]
# ### Calculating the Taylor microscale from the correlation function and the technique described in Chuychai et al

# %%
from scipy.optimize import curve_fit as cf
def f(x1,taylor):
    return (1-x1**2/(2*taylor**2))

def g(x1,corr_len):
    return np.exp(-x1/corr_len)

factor=index[1]-index[0] #to scale index of Rc to actual length
cr2=np.ndarray(160)    
ts2=np.ndarray(160)
j=0
for rmax in range(200,999,5):
    ts1=np.ndarray(rmax-99)
    cr1=np.ndarray(rmax-99)
    rfit=np.linspace(100,rmax,rmax-99).astype(int)
    i=0
    for rfit1 in rfit:
        range_=np.linspace(0,rfit1,rfit1+1).astype(int)
        p_opt, p_cov = cf(f,factor*range_,Rc[range_])
        p_opt2, p_cov2 = cf(g,factor*range_,Rc[range_])
        ts1[i]=p_opt
        cr1[i]=p_opt2
        i=i+1
    plt.plot(factor*rfit,ts1)
    plt.show()
    ts1_=interpolate.interp1d(factor*rfit,ts1,kind='linear',fill_value='extrapolate')
    cr1_=interpolate.interp1d(factor*rfit,cr1,kind='linear',fill_value='extrapolate')
    print(ts1_(0))
    ts2[j]=ts1_(0)
    cr2[j]=cr1_(0)
    j=j+1
print(ts2)
plt.plot(factor*np.linspace(200,999,160),ts2)
ts2_=interpolate.interp1d(factor*np.linspace(200,999,160),ts2,kind='linear',fill_value='extrapolate')
print(ts2_(0))
cr2_=interpolate.interp1d(factor*np.linspace(200,999,160),cr2,kind='linear',fill_value='extrapolate')
print(cr2_(0))
# Out:
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# 1943.483863263209
# ...
